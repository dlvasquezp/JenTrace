# %%
import sys
sys.path.append("C:\\Users\\Pandora\\Documents\\GitHub\\pyTrace\\src")

# %%
from opt_sys import OpSysData

#Create an object to store the lens data, by default ....
syst1 = OpSysData()

# %%
syst1.print_report()
syst1.plot_optical_system(clearSemDia_usr=[5])
# Out:
# SURFACE LIST
# Class:OpSysData
#     #     Distance    Curvature     Material         Type
#     0    10.000000     0.000000            1     standard
#     1     0.000000     0.000000            1     standard

# %%
# Add the lens information 
# link https://www.edmundoptics.de/p/125mm-dia-x-25mm-fl-mgfsub2sub-coated-achromatic-doublet-lens/2280/
syst1.add_surface(5.00 ,1/17.27   ,'N-BAF10')
syst1.add_surface(1.25 ,1/-10.99  ,'N-SF10')
syst1.add_surface(3    ,1/-107.03 ,1)

# %%
syst1.print_report()
syst1.plot_optical_system(clearSemDia_usr=[12.5/2])
# Out:
# SURFACE LIST
# Class:OpSysData
#     #     Distance    Curvature     Material         Type
#     0    10.000000     0.000000            1     standard
#     1     5.000000     0.057904      N-BAF10     standard
#     2     1.250000    -0.090992       N-SF10     standard
#     3     3.000000    -0.009343            1     standard
#     4     0.000000     0.000000            1     standard

# %%
#Add second
#Link https://www.edmundoptics.de/p/15mm-dia-x-45mm-fl-uncoated-double-convex-lens/18182/
#To change the las surface distance from the previus value 3mm to 1.0mm
syst1.change_surface(1.0    ,1/-107.03 ,1 ,surfIndex=3)

#Add the second lens
syst1.add_surface(3.00 ,1/ 45.99    ,'N-BK7')
syst1.add_surface(1.5  ,1/-45.99    ,1    )

# %%
syst1.print_report()
syst1.plot_optical_system(clearSemDia_usr=[5, 12.5/2, 12.5/2, 12.5/2, 15/2, 15/2, 5])
# Out:
# SURFACE LIST
# Class:OpSysData
#     #     Distance    Curvature     Material         Type
#     0    10.000000     0.000000            1     standard
#     1     5.000000     0.057904      N-BAF10     standard
#     2     1.250000    -0.090992       N-SF10     standard
#     3     1.000000    -0.009343            1     standard
#     4     3.000000     0.021744        N-BK7     standard
#     5     1.500000    -0.021744            1     standard
#     6     0.000000     0.000000            1     standard

# %%
#Add third lens
#https://www.edmundoptics.de/p/250mm-dia-x25-fl-uncoated-plano-concave-lens/5542/

#Add lens data
syst1.add_surface(3.50 ,1/ -19.62   ,'N-BK7')
syst1.add_surface(1.5  ,0           ,1    )

# %%
syst1.print_report()
syst1.plot_optical_system(clearSemDia_usr=[5, 12.5/2, 12.5/2, 12.5/2, 15/2, 15/2, 25/2, 25/2,  5])
# Out:
# SURFACE LIST
# Class:OpSysData
#     #     Distance    Curvature     Material         Type
#     0    10.000000     0.000000            1     standard
#     1     5.000000     0.057904      N-BAF10     standard
#     2     1.250000    -0.090992       N-SF10     standard
#     3     1.000000    -0.009343            1     standard
#     4     3.000000     0.021744        N-BK7     standard
#     5     1.500000    -0.021744            1     standard
#     6     3.500000    -0.050968        N-BK7     standard
#     7     1.500000     0.000000            1     standard
#     8     0.000000     0.000000            1     standard

# %%
from ray_src import RaySource

#Create a ray source to store data
pto1=RaySource()
#Add a ray to the ray source
pto1.new_ray([0,2,0],[0,0,1],587.6 )

# %%
pto1.print_report()
# Out:
# RAY LIST
# Class:RaySource
#     #         XPos         YPos         ZPos      XCosDir      YCosDir      ZCosDir   Wavelength
#     0     0.000000     2.000000     0.000000     0.000000     0.000000     1.000000   587.600000

# %%
from ray_trc import trace, print_report
from plt_fnc import plot_system, plot_rayTrace
import matplotlib.pyplot as plt

#Trace the ray through the optical system
trace1 = trace(pto1.RayList,syst1.SurfaceData)
print_report(trace1, 'ray',index=0)
# Out:
# RAYTRACE REPORT - RAY #0
#
#   Prop\Surf#       Object            1            2            3            4            5            6            7        Image
#            d    10.000000     5.000000     1.250000     1.000000     3.000000     1.500000     3.500000     1.500000     0.000000
#            c     0.000000     0.057904    -0.090992    -0.009343     0.021744    -0.021744    -0.050968     0.000000     0.000000
#            n     1.000000     1.670027     1.728272     1.000000     1.516798     1.000000     1.516798     1.000000     1.000000
#           X0     0.000000     0.000000     0.000000     0.000000     0.000000     0.000000     0.000000     0.000000     0.000000
#           Y0     0.000000     2.000000     1.771919     1.723535     1.642670     1.447022     1.272402     1.088111     0.966402
#            F     0.000000     0.231616    -0.285687    -0.027755     0.058673    -0.045529    -0.082518     0.000000     0.000000
#            G     0.000000     1.000000     0.991390     0.998583     0.999650     0.995847     0.985929     0.998578     0.996724
#        Delta     0.000000     0.116199    -0.145049    -0.013898     0.029356    -0.022865    -0.041893     0.000000     0.000000
#            X     0.000000     0.000000     0.000000     0.000000     0.000000     0.000000     0.000000     0.000000     0.000000
#            Y     2.000000     2.000000     1.778686     1.724084     1.640320     1.448507     1.277214     1.088111     0.966402
#            Z     0.000000     0.116199    -0.144892    -0.013887     0.029262    -0.022817    -0.041616     0.000000     0.000000
#       check1     1.000000     1.000000     1.000000     1.000000     1.000000     1.000000     1.000000     1.000000     1.000000
#         alfa     0.000000    -0.000000     0.000000     0.000000    -0.000000     0.000000     0.000000    -0.000000    -0.000000
#         beta     0.000000    -0.115808     0.161846     0.016108    -0.035667     0.031496     0.065098    -0.000000    -0.000000
#        gamma     0.000000     0.993272     0.986816     0.999870     0.999364     0.999504     0.997879     1.000000     1.000000
#       lambda   587.600000   587.600000   587.600000   587.600000   587.600000   587.600000   587.600000   587.600000   587.600000
#         cosI     0.000000     0.993272     0.978191     0.998453     0.999012     0.995350     0.983794     0.998578     0.996724
#        CosIp     0.000000     0.997593     0.979652     0.995373     0.999571     0.989268     0.992989     0.996724     0.996724
#            K     0.000000     0.038954    -0.005414     0.006823     0.011245     0.011317    -0.026624    -0.000000     0.000000
#            L     0.000000     0.000000     0.000000     0.000000     0.000000     0.000000     0.000000     0.000000     0.000000
#            M     0.000000    -0.046651    -0.039507    -0.080041    -0.064930    -0.114879    -0.053319    -0.080874    -0.080874
#            N     1.000000     0.998911     0.999219     0.996792     0.997890     0.993380     0.998578     0.996724     0.996724
#       Check2     1.000000     1.000000     1.000000     1.000000     1.000000     1.000000     1.000000     1.000000     1.000000
#     surfType     1.000000     1.000000     1.000000     1.000000     1.000000     1.000000     1.000000     1.000000     1.000000

# %%
fig, ax = plt.subplots()
fig, ax = plot_system(syst1,fig=fig,ax=ax,clearSemDia=[5, 12.5/2, 12.5/2, 12.5/2, 15/2, 15/2, 25/2, 25/2,  5])
fig, ax = plot_rayTrace(trace1,fig=fig,ax=ax,color='b')
